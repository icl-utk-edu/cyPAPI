# %% [markdown]
# # Tutorial 1: Querying configured components and available events
#
# Python is increasingly becoming performance conscious. Python 3.12 introduces profiling using linux perf. The Python community is keen on removing the Global Interpreter Lock (GIL) which would make Python truly multi-threaded multi-process. This can be expected to happen gradually over the next few Python releases.
#
# Python has a rich ecosystem for machine learning that includes libraries like Pytorch, Tensorflow, Scipy, FastAI, etc. These libraries support computation on GPUs in a native way.
#
# It would benefit the Python community to be able to access cross-platform native hardware counters to perform system-wide performance measurement and analysis. Thus, `CyPAPI` ports the `PAPI` library to meet that need.
#
# `CyPAPI` has been written in Cython as an extension module and provides all of PAPI functionality in a Pythonic object oriented way.

# %% [markdown]
# ## Importing `cypapi` and initialize library

# %%
from cypapi import *

# %% [markdown]
# The `PAPI` library has to be initialized with

# %%
pyPAPI_library_init()

# %% [markdown]
# To check the level of PAPI initialization

# %%
pyPAPI_is_initialized()
# Out:
# 1

# %% [markdown]
# `CyPAPI` supports PAPI version `>=7.0.0`. To check the version of the installed PAPI library

# %%
pyPAPI_get_version_string()
# Out:
# '7.0.1.0'

# %% [markdown]
# ### Components
#
# PAPI can be installed with any number of components. `CyPAPI` can retrieve information about each of these components.

# %%
num_cmp = pyPAPI_num_components()
num_cmp
# Out:
# 14

# %%
from papi.utils import papi_component_avail, papi_native_avail, papi_avail

# %%
papi_component_avail()
# Out:
# Component 0: perf_event
# 	Description:	Linux perf_event CPU counters
# 	Num events:	165
# Component 1: perf_event_uncore
# 	Description:	Linux perf_event CPU uncore and northbridge
# 	Num events:	1126
# Component 2: cuda
# 	Description:	CUDA profiling via NVIDIA CuPTI interfaces
# 	Num events:	1134672
# Component 3: nvml
# 	Description:	NVML provides the API for monitoring NVIDIA hardware (power usage, temperature, fan speed, etc)
# 	Num events:	216
# Component 4: lmsensors
# 	Description:	lm-sensors provides tools for monitoring the hardware health
# 	Num events:	170
# Component 5: sde
# 	Description:	Software Defined Events (SDE) component
# 	Num events:	0
# Component 6: io
# 	Description:	A component to read /proc/self/io
# 	Num events:	7
# Component 7: coretemp
# 	Description:	Linux hwmon temperature and other info
# 	Num events:	42
# Component 8: net
# 	Description:	Linux network driver statistics
# 	Num events:	160
# Component 9: powercap
# 	Description:	Linux powercap energy measurements
# 	Num events:	30
# Component 10: rapl
# 	Description:	Linux RAPL energy measurements
# 	Disabled -3:	Can't open fd for cpu0: Permission denied
# Component 11: stealtime
# 	Description:	Stealtime filesystem statistics
# 	Num events:	81
# Component 12: appio
# 	Description:
# 	Num events:	45
# Component 13: sysdetect
# 	Description:	System info detection component
# 	Num events:	0

# %% [markdown]
# ## Events in component
#
# Each of these components have events that can be measured.

# %%
cuda_evts = papi_native_avail(2)
cuda_evts
# Out:
# ['cuda:::dram__bytes.avg.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__bytes.avg.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes.avg.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__bytes.avg.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__bytes.avg.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__bytes.avg.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes.avg.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__bytes.avg.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__bytes.avg.peak_burst:device=0',
#  'cuda:::dram__bytes.avg.peak_burst_active:device=0',
#  'cuda:::dram__bytes.avg.peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes.avg.peak_burst_frame:device=0',
#  'cuda:::dram__bytes.avg.peak_burst_region:device=0',
#  'cuda:::dram__bytes.avg.peak_sustained:device=0',
#  'cuda:::dram__bytes.avg.peak_sustained_active:device=0',
#  'cuda:::dram__bytes.avg.peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes.avg.peak_sustained_frame:device=0',
#  'cuda:::dram__bytes.avg.peak_sustained_region:device=0',
#  'cuda:::dram__bytes.avg.per_cycle_active:device=0',
#  'cuda:::dram__bytes.avg.per_cycle_elapsed:device=0',
#  'cuda:::dram__bytes.avg.per_cycle_in_frame:device=0',
#  'cuda:::dram__bytes.avg.per_cycle_in_region:device=0',
#  'cuda:::dram__bytes.avg.per_second:device=0',
#  'cuda:::dram__bytes.max:device=0',
#  'cuda:::dram__bytes.max.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__bytes.max.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes.max.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__bytes.max.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__bytes.max.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__bytes.max.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes.max.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__bytes.max.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__bytes.max.peak_burst:device=0',
#  'cuda:::dram__bytes.max.peak_burst_active:device=0',
#  'cuda:::dram__bytes.max.peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes.max.peak_burst_frame:device=0',
#  'cuda:::dram__bytes.max.peak_burst_region:device=0',
#  'cuda:::dram__bytes.max.peak_sustained:device=0',
#  'cuda:::dram__bytes.max.peak_sustained_active:device=0',
#  'cuda:::dram__bytes.max.peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes.max.peak_sustained_frame:device=0',
#  'cuda:::dram__bytes.max.peak_sustained_region:device=0',
#  'cuda:::dram__bytes.max.per_cycle_active:device=0',
#  'cuda:::dram__bytes.max.per_cycle_elapsed:device=0',
#  'cuda:::dram__bytes.max.per_cycle_in_frame:device=0',
#  'cuda:::dram__bytes.max.per_cycle_in_region:device=0',
#  'cuda:::dram__bytes.max.per_second:device=0',
#  'cuda:::dram__bytes.min:device=0',
#  'cuda:::dram__bytes.min.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__bytes.min.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes.min.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__bytes.min.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__bytes.min.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__bytes.min.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes.min.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__bytes.min.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__bytes.min.peak_burst:device=0',
#  'cuda:::dram__bytes.min.peak_burst_active:device=0',
#  'cuda:::dram__bytes.min.peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes.min.peak_burst_frame:device=0',
#  'cuda:::dram__bytes.min.peak_burst_region:device=0',
#  'cuda:::dram__bytes.min.peak_sustained:device=0',
#  'cuda:::dram__bytes.min.peak_sustained_active:device=0',
#  'cuda:::dram__bytes.min.peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes.min.peak_sustained_frame:device=0',
#  'cuda:::dram__bytes.min.peak_sustained_region:device=0',
#  'cuda:::dram__bytes.min.per_cycle_active:device=0',
#  'cuda:::dram__bytes.min.per_cycle_elapsed:device=0',
#  'cuda:::dram__bytes.min.per_cycle_in_frame:device=0',
#  'cuda:::dram__bytes.min.per_cycle_in_region:device=0',
#  'cuda:::dram__bytes.min.per_second:device=0',
#  'cuda:::dram__bytes.sum:device=0',
#  'cuda:::dram__bytes.sum.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__bytes.sum.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes.sum.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__bytes.sum.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__bytes.sum.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__bytes.sum.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes.sum.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__bytes.sum.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__bytes.sum.peak_burst:device=0',
#  'cuda:::dram__bytes.sum.peak_burst_active:device=0',
#  'cuda:::dram__bytes.sum.peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes.sum.peak_burst_frame:device=0',
#  'cuda:::dram__bytes.sum.peak_burst_region:device=0',
#  'cuda:::dram__bytes.sum.peak_sustained:device=0',
#  'cuda:::dram__bytes.sum.peak_sustained_active:device=0',
#  'cuda:::dram__bytes.sum.peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes.sum.peak_sustained_frame:device=0',
#  'cuda:::dram__bytes.sum.peak_sustained_region:device=0',
#  'cuda:::dram__bytes.sum.per_cycle_active:device=0',
#  'cuda:::dram__bytes.sum.per_cycle_elapsed:device=0',
#  'cuda:::dram__bytes.sum.per_cycle_in_frame:device=0',
#  'cuda:::dram__bytes.sum.per_cycle_in_region:device=0',
#  'cuda:::dram__bytes.sum.per_second:device=0',
#  'cuda:::dram__bytes_read.avg:device=0',
#  'cuda:::dram__bytes_read.avg.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__bytes_read.avg.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes_read.avg.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__bytes_read.avg.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__bytes_read.avg.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__bytes_read.avg.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes_read.avg.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__bytes_read.avg.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__bytes_read.avg.peak_burst:device=0',
#  'cuda:::dram__bytes_read.avg.peak_burst_active:device=0',
#  'cuda:::dram__bytes_read.avg.peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes_read.avg.peak_burst_frame:device=0',
#  'cuda:::dram__bytes_read.avg.peak_burst_region:device=0',
#  'cuda:::dram__bytes_read.avg.peak_sustained:device=0',
#  'cuda:::dram__bytes_read.avg.peak_sustained_active:device=0',
#  'cuda:::dram__bytes_read.avg.peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes_read.avg.peak_sustained_frame:device=0',
#  'cuda:::dram__bytes_read.avg.peak_sustained_region:device=0',
#  'cuda:::dram__bytes_read.avg.per_cycle_active:device=0',
#  'cuda:::dram__bytes_read.avg.per_cycle_elapsed:device=0',
#  'cuda:::dram__bytes_read.avg.per_cycle_in_frame:device=0',
#  'cuda:::dram__bytes_read.avg.per_cycle_in_region:device=0',
#  'cuda:::dram__bytes_read.avg.per_second:device=0',
#  'cuda:::dram__bytes_read.max:device=0',
#  'cuda:::dram__bytes_read.max.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__bytes_read.max.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes_read.max.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__bytes_read.max.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__bytes_read.max.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__bytes_read.max.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes_read.max.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__bytes_read.max.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__bytes_read.max.peak_burst:device=0',
#  'cuda:::dram__bytes_read.max.peak_burst_active:device=0',
#  'cuda:::dram__bytes_read.max.peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes_read.max.peak_burst_frame:device=0',
#  'cuda:::dram__bytes_read.max.peak_burst_region:device=0',
#  'cuda:::dram__bytes_read.max.peak_sustained:device=0',
#  'cuda:::dram__bytes_read.max.peak_sustained_active:device=0',
#  'cuda:::dram__bytes_read.max.peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes_read.max.peak_sustained_frame:device=0',
#  'cuda:::dram__bytes_read.max.peak_sustained_region:device=0',
#  'cuda:::dram__bytes_read.max.per_cycle_active:device=0',
#  'cuda:::dram__bytes_read.max.per_cycle_elapsed:device=0',
#  'cuda:::dram__bytes_read.max.per_cycle_in_frame:device=0',
#  'cuda:::dram__bytes_read.max.per_cycle_in_region:device=0',
#  'cuda:::dram__bytes_read.max.per_second:device=0',
#  'cuda:::dram__bytes_read.min:device=0',
#  'cuda:::dram__bytes_read.min.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__bytes_read.min.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes_read.min.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__bytes_read.min.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__bytes_read.min.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__bytes_read.min.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes_read.min.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__bytes_read.min.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__bytes_read.min.peak_burst:device=0',
#  'cuda:::dram__bytes_read.min.peak_burst_active:device=0',
#  'cuda:::dram__bytes_read.min.peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes_read.min.peak_burst_frame:device=0',
#  'cuda:::dram__bytes_read.min.peak_burst_region:device=0',
#  'cuda:::dram__bytes_read.min.peak_sustained:device=0',
#  'cuda:::dram__bytes_read.min.peak_sustained_active:device=0',
#  'cuda:::dram__bytes_read.min.peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes_read.min.peak_sustained_frame:device=0',
#  'cuda:::dram__bytes_read.min.peak_sustained_region:device=0',
#  'cuda:::dram__bytes_read.min.per_cycle_active:device=0',
#  'cuda:::dram__bytes_read.min.per_cycle_elapsed:device=0',
#  'cuda:::dram__bytes_read.min.per_cycle_in_frame:device=0',
#  'cuda:::dram__bytes_read.min.per_cycle_in_region:device=0',
#  'cuda:::dram__bytes_read.min.per_second:device=0',
#  'cuda:::dram__bytes_read.sum:device=0',
#  'cuda:::dram__bytes_read.sum.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__bytes_read.sum.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes_read.sum.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__bytes_read.sum.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__bytes_read.sum.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__bytes_read.sum.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes_read.sum.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__bytes_read.sum.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__bytes_read.sum.peak_burst:device=0',
#  'cuda:::dram__bytes_read.sum.peak_burst_active:device=0',
#  'cuda:::dram__bytes_read.sum.peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes_read.sum.peak_burst_frame:device=0',
#  'cuda:::dram__bytes_read.sum.peak_burst_region:device=0',
#  'cuda:::dram__bytes_read.sum.peak_sustained:device=0',
#  'cuda:::dram__bytes_read.sum.peak_sustained_active:device=0',
#  'cuda:::dram__bytes_read.sum.peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes_read.sum.peak_sustained_frame:device=0',
#  'cuda:::dram__bytes_read.sum.peak_sustained_region:device=0',
#  'cuda:::dram__bytes_read.sum.per_cycle_active:device=0',
#  'cuda:::dram__bytes_read.sum.per_cycle_elapsed:device=0',
#  'cuda:::dram__bytes_read.sum.per_cycle_in_frame:device=0',
#  'cuda:::dram__bytes_read.sum.per_cycle_in_region:device=0',
#  'cuda:::dram__bytes_read.sum.per_second:device=0',
#  'cuda:::dram__bytes_write.avg:device=0',
#  'cuda:::dram__bytes_write.avg.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__bytes_write.avg.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes_write.avg.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__bytes_write.avg.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__bytes_write.avg.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__bytes_write.avg.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes_write.avg.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__bytes_write.avg.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__bytes_write.avg.peak_burst:device=0',
#  'cuda:::dram__bytes_write.avg.peak_burst_active:device=0',
#  'cuda:::dram__bytes_write.avg.peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes_write.avg.peak_burst_frame:device=0',
#  'cuda:::dram__bytes_write.avg.peak_burst_region:device=0',
#  'cuda:::dram__bytes_write.avg.peak_sustained:device=0',
#  'cuda:::dram__bytes_write.avg.peak_sustained_active:device=0',
#  'cuda:::dram__bytes_write.avg.peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes_write.avg.peak_sustained_frame:device=0',
#  'cuda:::dram__bytes_write.avg.peak_sustained_region:device=0',
#  'cuda:::dram__bytes_write.avg.per_cycle_active:device=0',
#  'cuda:::dram__bytes_write.avg.per_cycle_elapsed:device=0',
#  'cuda:::dram__bytes_write.avg.per_cycle_in_frame:device=0',
#  'cuda:::dram__bytes_write.avg.per_cycle_in_region:device=0',
#  'cuda:::dram__bytes_write.avg.per_second:device=0',
#  'cuda:::dram__bytes_write.max:device=0',
#  'cuda:::dram__bytes_write.max.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__bytes_write.max.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes_write.max.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__bytes_write.max.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__bytes_write.max.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__bytes_write.max.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes_write.max.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__bytes_write.max.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__bytes_write.max.peak_burst:device=0',
#  'cuda:::dram__bytes_write.max.peak_burst_active:device=0',
#  'cuda:::dram__bytes_write.max.peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes_write.max.peak_burst_frame:device=0',
#  'cuda:::dram__bytes_write.max.peak_burst_region:device=0',
#  'cuda:::dram__bytes_write.max.peak_sustained:device=0',
#  'cuda:::dram__bytes_write.max.peak_sustained_active:device=0',
#  'cuda:::dram__bytes_write.max.peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes_write.max.peak_sustained_frame:device=0',
#  'cuda:::dram__bytes_write.max.peak_sustained_region:device=0',
#  'cuda:::dram__bytes_write.max.per_cycle_active:device=0',
#  'cuda:::dram__bytes_write.max.per_cycle_elapsed:device=0',
#  'cuda:::dram__bytes_write.max.per_cycle_in_frame:device=0',
#  'cuda:::dram__bytes_write.max.per_cycle_in_region:device=0',
#  'cuda:::dram__bytes_write.max.per_second:device=0',
#  'cuda:::dram__bytes_write.min:device=0',
#  'cuda:::dram__bytes_write.min.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__bytes_write.min.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes_write.min.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__bytes_write.min.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__bytes_write.min.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__bytes_write.min.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes_write.min.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__bytes_write.min.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__bytes_write.min.peak_burst:device=0',
#  'cuda:::dram__bytes_write.min.peak_burst_active:device=0',
#  'cuda:::dram__bytes_write.min.peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes_write.min.peak_burst_frame:device=0',
#  'cuda:::dram__bytes_write.min.peak_burst_region:device=0',
#  'cuda:::dram__bytes_write.min.peak_sustained:device=0',
#  'cuda:::dram__bytes_write.min.peak_sustained_active:device=0',
#  'cuda:::dram__bytes_write.min.peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes_write.min.peak_sustained_frame:device=0',
#  'cuda:::dram__bytes_write.min.peak_sustained_region:device=0',
#  'cuda:::dram__bytes_write.min.per_cycle_active:device=0',
#  'cuda:::dram__bytes_write.min.per_cycle_elapsed:device=0',
#  'cuda:::dram__bytes_write.min.per_cycle_in_frame:device=0',
#  'cuda:::dram__bytes_write.min.per_cycle_in_region:device=0',
#  'cuda:::dram__bytes_write.min.per_second:device=0',
#  'cuda:::dram__bytes_write.sum:device=0',
#  'cuda:::dram__bytes_write.sum.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__bytes_write.sum.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes_write.sum.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__bytes_write.sum.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__bytes_write.sum.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__bytes_write.sum.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes_write.sum.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__bytes_write.sum.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__bytes_write.sum.peak_burst:device=0',
#  'cuda:::dram__bytes_write.sum.peak_burst_active:device=0',
#  'cuda:::dram__bytes_write.sum.peak_burst_elapsed:device=0',
#  'cuda:::dram__bytes_write.sum.peak_burst_frame:device=0',
#  'cuda:::dram__bytes_write.sum.peak_burst_region:device=0',
#  'cuda:::dram__bytes_write.sum.peak_sustained:device=0',
#  'cuda:::dram__bytes_write.sum.peak_sustained_active:device=0',
#  'cuda:::dram__bytes_write.sum.peak_sustained_elapsed:device=0',
#  'cuda:::dram__bytes_write.sum.peak_sustained_frame:device=0',
#  'cuda:::dram__bytes_write.sum.peak_sustained_region:device=0',
#  'cuda:::dram__bytes_write.sum.per_cycle_active:device=0',
#  'cuda:::dram__bytes_write.sum.per_cycle_elapsed:device=0',
#  'cuda:::dram__bytes_write.sum.per_cycle_in_frame:device=0',
#  'cuda:::dram__bytes_write.sum.per_cycle_in_region:device=0',
#  'cuda:::dram__bytes_write.sum.per_second:device=0',
#  'cuda:::dram__cycles_active.avg:device=0',
#  'cuda:::dram__cycles_active.avg.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_active.avg.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active.avg.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active.avg.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_active.avg.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active.avg.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active.avg.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active.avg.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active.avg.peak_burst:device=0',
#  'cuda:::dram__cycles_active.avg.peak_burst_active:device=0',
#  'cuda:::dram__cycles_active.avg.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active.avg.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active.avg.peak_burst_region:device=0',
#  'cuda:::dram__cycles_active.avg.peak_sustained:device=0',
#  'cuda:::dram__cycles_active.avg.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active.avg.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active.avg.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active.avg.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active.avg.per_cycle_active:device=0',
#  'cuda:::dram__cycles_active.avg.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_active.avg.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_active.avg.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_active.avg.per_second:device=0',
#  'cuda:::dram__cycles_active.max:device=0',
#  'cuda:::dram__cycles_active.max.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_active.max.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active.max.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active.max.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_active.max.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active.max.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active.max.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active.max.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active.max.peak_burst:device=0',
#  'cuda:::dram__cycles_active.max.peak_burst_active:device=0',
#  'cuda:::dram__cycles_active.max.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active.max.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active.max.peak_burst_region:device=0',
#  'cuda:::dram__cycles_active.max.peak_sustained:device=0',
#  'cuda:::dram__cycles_active.max.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active.max.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active.max.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active.max.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active.max.per_cycle_active:device=0',
#  'cuda:::dram__cycles_active.max.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_active.max.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_active.max.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_active.max.per_second:device=0',
#  'cuda:::dram__cycles_active.min:device=0',
#  'cuda:::dram__cycles_active.min.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_active.min.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active.min.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active.min.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_active.min.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active.min.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active.min.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active.min.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active.min.peak_burst:device=0',
#  'cuda:::dram__cycles_active.min.peak_burst_active:device=0',
#  'cuda:::dram__cycles_active.min.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active.min.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active.min.peak_burst_region:device=0',
#  'cuda:::dram__cycles_active.min.peak_sustained:device=0',
#  'cuda:::dram__cycles_active.min.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active.min.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active.min.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active.min.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active.min.per_cycle_active:device=0',
#  'cuda:::dram__cycles_active.min.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_active.min.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_active.min.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_active.min.per_second:device=0',
#  'cuda:::dram__cycles_active.sum:device=0',
#  'cuda:::dram__cycles_active.sum.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_active.sum.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active.sum.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active.sum.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_active.sum.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active.sum.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active.sum.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active.sum.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active.sum.peak_burst:device=0',
#  'cuda:::dram__cycles_active.sum.peak_burst_active:device=0',
#  'cuda:::dram__cycles_active.sum.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active.sum.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active.sum.peak_burst_region:device=0',
#  'cuda:::dram__cycles_active.sum.peak_sustained:device=0',
#  'cuda:::dram__cycles_active.sum.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active.sum.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active.sum.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active.sum.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active.sum.per_cycle_active:device=0',
#  'cuda:::dram__cycles_active.sum.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_active.sum.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_active.sum.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_active.sum.per_second:device=0',
#  'cuda:::dram__cycles_active_read.avg:device=0',
#  'cuda:::dram__cycles_active_read.avg.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_active_read.avg.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active_read.avg.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active_read.avg.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_active_read.avg.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active_read.avg.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active_read.avg.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active_read.avg.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active_read.avg.peak_burst:device=0',
#  'cuda:::dram__cycles_active_read.avg.peak_burst_active:device=0',
#  'cuda:::dram__cycles_active_read.avg.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active_read.avg.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active_read.avg.peak_burst_region:device=0',
#  'cuda:::dram__cycles_active_read.avg.peak_sustained:device=0',
#  'cuda:::dram__cycles_active_read.avg.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active_read.avg.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active_read.avg.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active_read.avg.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active_read.avg.per_cycle_active:device=0',
#  'cuda:::dram__cycles_active_read.avg.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_active_read.avg.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_active_read.avg.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_active_read.avg.per_second:device=0',
#  'cuda:::dram__cycles_active_read.max:device=0',
#  'cuda:::dram__cycles_active_read.max.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_active_read.max.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active_read.max.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active_read.max.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_active_read.max.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active_read.max.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active_read.max.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active_read.max.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active_read.max.peak_burst:device=0',
#  'cuda:::dram__cycles_active_read.max.peak_burst_active:device=0',
#  'cuda:::dram__cycles_active_read.max.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active_read.max.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active_read.max.peak_burst_region:device=0',
#  'cuda:::dram__cycles_active_read.max.peak_sustained:device=0',
#  'cuda:::dram__cycles_active_read.max.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active_read.max.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active_read.max.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active_read.max.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active_read.max.per_cycle_active:device=0',
#  'cuda:::dram__cycles_active_read.max.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_active_read.max.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_active_read.max.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_active_read.max.per_second:device=0',
#  'cuda:::dram__cycles_active_read.min:device=0',
#  'cuda:::dram__cycles_active_read.min.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_active_read.min.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active_read.min.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active_read.min.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_active_read.min.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active_read.min.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active_read.min.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active_read.min.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active_read.min.peak_burst:device=0',
#  'cuda:::dram__cycles_active_read.min.peak_burst_active:device=0',
#  'cuda:::dram__cycles_active_read.min.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active_read.min.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active_read.min.peak_burst_region:device=0',
#  'cuda:::dram__cycles_active_read.min.peak_sustained:device=0',
#  'cuda:::dram__cycles_active_read.min.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active_read.min.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active_read.min.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active_read.min.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active_read.min.per_cycle_active:device=0',
#  'cuda:::dram__cycles_active_read.min.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_active_read.min.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_active_read.min.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_active_read.min.per_second:device=0',
#  'cuda:::dram__cycles_active_read.sum:device=0',
#  'cuda:::dram__cycles_active_read.sum.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_active_read.sum.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active_read.sum.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active_read.sum.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_active_read.sum.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active_read.sum.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active_read.sum.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active_read.sum.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active_read.sum.peak_burst:device=0',
#  'cuda:::dram__cycles_active_read.sum.peak_burst_active:device=0',
#  'cuda:::dram__cycles_active_read.sum.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active_read.sum.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active_read.sum.peak_burst_region:device=0',
#  'cuda:::dram__cycles_active_read.sum.peak_sustained:device=0',
#  'cuda:::dram__cycles_active_read.sum.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active_read.sum.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active_read.sum.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active_read.sum.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active_read.sum.per_cycle_active:device=0',
#  'cuda:::dram__cycles_active_read.sum.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_active_read.sum.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_active_read.sum.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_active_read.sum.per_second:device=0',
#  'cuda:::dram__cycles_active_write.avg:device=0',
#  'cuda:::dram__cycles_active_write.avg.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_active_write.avg.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active_write.avg.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active_write.avg.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_active_write.avg.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active_write.avg.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active_write.avg.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active_write.avg.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active_write.avg.peak_burst:device=0',
#  'cuda:::dram__cycles_active_write.avg.peak_burst_active:device=0',
#  'cuda:::dram__cycles_active_write.avg.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active_write.avg.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active_write.avg.peak_burst_region:device=0',
#  'cuda:::dram__cycles_active_write.avg.peak_sustained:device=0',
#  'cuda:::dram__cycles_active_write.avg.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active_write.avg.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active_write.avg.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active_write.avg.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active_write.avg.per_cycle_active:device=0',
#  'cuda:::dram__cycles_active_write.avg.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_active_write.avg.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_active_write.avg.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_active_write.avg.per_second:device=0',
#  'cuda:::dram__cycles_active_write.max:device=0',
#  'cuda:::dram__cycles_active_write.max.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_active_write.max.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active_write.max.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active_write.max.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_active_write.max.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active_write.max.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active_write.max.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active_write.max.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active_write.max.peak_burst:device=0',
#  'cuda:::dram__cycles_active_write.max.peak_burst_active:device=0',
#  'cuda:::dram__cycles_active_write.max.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active_write.max.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active_write.max.peak_burst_region:device=0',
#  'cuda:::dram__cycles_active_write.max.peak_sustained:device=0',
#  'cuda:::dram__cycles_active_write.max.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active_write.max.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active_write.max.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active_write.max.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active_write.max.per_cycle_active:device=0',
#  'cuda:::dram__cycles_active_write.max.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_active_write.max.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_active_write.max.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_active_write.max.per_second:device=0',
#  'cuda:::dram__cycles_active_write.min:device=0',
#  'cuda:::dram__cycles_active_write.min.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_active_write.min.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active_write.min.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active_write.min.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_active_write.min.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active_write.min.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active_write.min.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active_write.min.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active_write.min.peak_burst:device=0',
#  'cuda:::dram__cycles_active_write.min.peak_burst_active:device=0',
#  'cuda:::dram__cycles_active_write.min.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active_write.min.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active_write.min.peak_burst_region:device=0',
#  'cuda:::dram__cycles_active_write.min.peak_sustained:device=0',
#  'cuda:::dram__cycles_active_write.min.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active_write.min.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active_write.min.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active_write.min.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active_write.min.per_cycle_active:device=0',
#  'cuda:::dram__cycles_active_write.min.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_active_write.min.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_active_write.min.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_active_write.min.per_second:device=0',
#  'cuda:::dram__cycles_active_write.sum:device=0',
#  'cuda:::dram__cycles_active_write.sum.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_active_write.sum.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active_write.sum.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active_write.sum.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_active_write.sum.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active_write.sum.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active_write.sum.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active_write.sum.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active_write.sum.peak_burst:device=0',
#  'cuda:::dram__cycles_active_write.sum.peak_burst_active:device=0',
#  'cuda:::dram__cycles_active_write.sum.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_active_write.sum.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_active_write.sum.peak_burst_region:device=0',
#  'cuda:::dram__cycles_active_write.sum.peak_sustained:device=0',
#  'cuda:::dram__cycles_active_write.sum.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_active_write.sum.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_active_write.sum.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_active_write.sum.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_active_write.sum.per_cycle_active:device=0',
#  'cuda:::dram__cycles_active_write.sum.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_active_write.sum.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_active_write.sum.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_active_write.sum.per_second:device=0',
#  'cuda:::dram__cycles_elapsed.avg:device=0',
#  'cuda:::dram__cycles_elapsed.avg.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_elapsed.avg.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_elapsed.avg.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_elapsed.avg.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_elapsed.avg.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_elapsed.avg.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_elapsed.avg.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_elapsed.avg.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_elapsed.avg.peak_burst:device=0',
#  'cuda:::dram__cycles_elapsed.avg.peak_burst_active:device=0',
#  'cuda:::dram__cycles_elapsed.avg.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_elapsed.avg.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_elapsed.avg.peak_burst_region:device=0',
#  'cuda:::dram__cycles_elapsed.avg.peak_sustained:device=0',
#  'cuda:::dram__cycles_elapsed.avg.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_elapsed.avg.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_elapsed.avg.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_elapsed.avg.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_elapsed.avg.per_cycle_active:device=0',
#  'cuda:::dram__cycles_elapsed.avg.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_elapsed.avg.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_elapsed.avg.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_elapsed.avg.per_second:device=0',
#  'cuda:::dram__cycles_elapsed.max:device=0',
#  'cuda:::dram__cycles_elapsed.max.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_elapsed.max.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_elapsed.max.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_elapsed.max.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_elapsed.max.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_elapsed.max.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_elapsed.max.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_elapsed.max.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_elapsed.max.peak_burst:device=0',
#  'cuda:::dram__cycles_elapsed.max.peak_burst_active:device=0',
#  'cuda:::dram__cycles_elapsed.max.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_elapsed.max.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_elapsed.max.peak_burst_region:device=0',
#  'cuda:::dram__cycles_elapsed.max.peak_sustained:device=0',
#  'cuda:::dram__cycles_elapsed.max.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_elapsed.max.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_elapsed.max.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_elapsed.max.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_elapsed.max.per_cycle_active:device=0',
#  'cuda:::dram__cycles_elapsed.max.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_elapsed.max.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_elapsed.max.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_elapsed.max.per_second:device=0',
#  'cuda:::dram__cycles_elapsed.min:device=0',
#  'cuda:::dram__cycles_elapsed.min.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_elapsed.min.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_elapsed.min.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_elapsed.min.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_elapsed.min.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_elapsed.min.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_elapsed.min.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_elapsed.min.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_elapsed.min.peak_burst:device=0',
#  'cuda:::dram__cycles_elapsed.min.peak_burst_active:device=0',
#  'cuda:::dram__cycles_elapsed.min.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_elapsed.min.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_elapsed.min.peak_burst_region:device=0',
#  'cuda:::dram__cycles_elapsed.min.peak_sustained:device=0',
#  'cuda:::dram__cycles_elapsed.min.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_elapsed.min.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_elapsed.min.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_elapsed.min.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_elapsed.min.per_cycle_active:device=0',
#  'cuda:::dram__cycles_elapsed.min.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_elapsed.min.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_elapsed.min.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_elapsed.min.per_second:device=0',
#  'cuda:::dram__cycles_elapsed.sum:device=0',
#  'cuda:::dram__cycles_elapsed.sum.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_elapsed.sum.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_elapsed.sum.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_elapsed.sum.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_elapsed.sum.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_elapsed.sum.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_elapsed.sum.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_elapsed.sum.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_elapsed.sum.peak_burst:device=0',
#  'cuda:::dram__cycles_elapsed.sum.peak_burst_active:device=0',
#  'cuda:::dram__cycles_elapsed.sum.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_elapsed.sum.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_elapsed.sum.peak_burst_region:device=0',
#  'cuda:::dram__cycles_elapsed.sum.peak_sustained:device=0',
#  'cuda:::dram__cycles_elapsed.sum.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_elapsed.sum.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_elapsed.sum.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_elapsed.sum.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_elapsed.sum.per_cycle_active:device=0',
#  'cuda:::dram__cycles_elapsed.sum.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_elapsed.sum.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_elapsed.sum.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_elapsed.sum.per_second:device=0',
#  'cuda:::dram__cycles_in_frame.avg:device=0',
#  'cuda:::dram__cycles_in_frame.avg.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_in_frame.avg.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_in_frame.avg.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_in_frame.avg.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_in_frame.avg.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_in_frame.avg.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_in_frame.avg.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_in_frame.avg.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_in_frame.avg.peak_burst:device=0',
#  'cuda:::dram__cycles_in_frame.avg.peak_burst_active:device=0',
#  'cuda:::dram__cycles_in_frame.avg.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_in_frame.avg.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_in_frame.avg.peak_burst_region:device=0',
#  'cuda:::dram__cycles_in_frame.avg.peak_sustained:device=0',
#  'cuda:::dram__cycles_in_frame.avg.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_in_frame.avg.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_in_frame.avg.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_in_frame.avg.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_in_frame.avg.per_cycle_active:device=0',
#  'cuda:::dram__cycles_in_frame.avg.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_in_frame.avg.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_in_frame.avg.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_in_frame.avg.per_second:device=0',
#  'cuda:::dram__cycles_in_frame.max:device=0',
#  'cuda:::dram__cycles_in_frame.max.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_in_frame.max.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_in_frame.max.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_in_frame.max.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_in_frame.max.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_in_frame.max.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_in_frame.max.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_in_frame.max.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_in_frame.max.peak_burst:device=0',
#  'cuda:::dram__cycles_in_frame.max.peak_burst_active:device=0',
#  'cuda:::dram__cycles_in_frame.max.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_in_frame.max.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_in_frame.max.peak_burst_region:device=0',
#  'cuda:::dram__cycles_in_frame.max.peak_sustained:device=0',
#  'cuda:::dram__cycles_in_frame.max.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_in_frame.max.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_in_frame.max.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_in_frame.max.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_in_frame.max.per_cycle_active:device=0',
#  'cuda:::dram__cycles_in_frame.max.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_in_frame.max.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_in_frame.max.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_in_frame.max.per_second:device=0',
#  'cuda:::dram__cycles_in_frame.min:device=0',
#  'cuda:::dram__cycles_in_frame.min.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_in_frame.min.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_in_frame.min.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_in_frame.min.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_in_frame.min.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_in_frame.min.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_in_frame.min.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_in_frame.min.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_in_frame.min.peak_burst:device=0',
#  'cuda:::dram__cycles_in_frame.min.peak_burst_active:device=0',
#  'cuda:::dram__cycles_in_frame.min.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_in_frame.min.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_in_frame.min.peak_burst_region:device=0',
#  'cuda:::dram__cycles_in_frame.min.peak_sustained:device=0',
#  'cuda:::dram__cycles_in_frame.min.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_in_frame.min.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_in_frame.min.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_in_frame.min.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_in_frame.min.per_cycle_active:device=0',
#  'cuda:::dram__cycles_in_frame.min.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_in_frame.min.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_in_frame.min.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_in_frame.min.per_second:device=0',
#  'cuda:::dram__cycles_in_frame.sum:device=0',
#  'cuda:::dram__cycles_in_frame.sum.pct_of_peak_burst_active:device=0',
# ...
#  'cuda:::dram__cycles_in_frame.sum.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_in_frame.sum.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_in_frame.sum.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_in_frame.sum.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_in_frame.sum.peak_burst:device=0',
#  'cuda:::dram__cycles_in_frame.sum.peak_burst_active:device=0',
#  'cuda:::dram__cycles_in_frame.sum.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_in_frame.sum.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_in_frame.sum.peak_burst_region:device=0',
#  'cuda:::dram__cycles_in_frame.sum.peak_sustained:device=0',
#  'cuda:::dram__cycles_in_frame.sum.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_in_frame.sum.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_in_frame.sum.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_in_frame.sum.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_in_frame.sum.per_cycle_active:device=0',
#  'cuda:::dram__cycles_in_frame.sum.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_in_frame.sum.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_in_frame.sum.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_in_frame.sum.per_second:device=0',
#  'cuda:::dram__cycles_in_region.avg:device=0',
#  'cuda:::dram__cycles_in_region.avg.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_in_region.avg.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_in_region.avg.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_in_region.avg.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_in_region.avg.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_in_region.avg.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_in_region.avg.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_in_region.avg.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_in_region.avg.peak_burst:device=0',
#  'cuda:::dram__cycles_in_region.avg.peak_burst_active:device=0',
#  'cuda:::dram__cycles_in_region.avg.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_in_region.avg.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_in_region.avg.peak_burst_region:device=0',
#  'cuda:::dram__cycles_in_region.avg.peak_sustained:device=0',
#  'cuda:::dram__cycles_in_region.avg.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_in_region.avg.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_in_region.avg.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_in_region.avg.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_in_region.avg.per_cycle_active:device=0',
#  'cuda:::dram__cycles_in_region.avg.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_in_region.avg.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_in_region.avg.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_in_region.avg.per_second:device=0',
#  'cuda:::dram__cycles_in_region.max:device=0',
#  'cuda:::dram__cycles_in_region.max.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_in_region.max.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_in_region.max.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_in_region.max.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_in_region.max.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_in_region.max.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_in_region.max.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_in_region.max.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_in_region.max.peak_burst:device=0',
#  'cuda:::dram__cycles_in_region.max.peak_burst_active:device=0',
#  'cuda:::dram__cycles_in_region.max.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_in_region.max.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_in_region.max.peak_burst_region:device=0',
#  'cuda:::dram__cycles_in_region.max.peak_sustained:device=0',
#  'cuda:::dram__cycles_in_region.max.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_in_region.max.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_in_region.max.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_in_region.max.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_in_region.max.per_cycle_active:device=0',
#  'cuda:::dram__cycles_in_region.max.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_in_region.max.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_in_region.max.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_in_region.max.per_second:device=0',
#  'cuda:::dram__cycles_in_region.min:device=0',
#  'cuda:::dram__cycles_in_region.min.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_in_region.min.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_in_region.min.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_in_region.min.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_in_region.min.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_in_region.min.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_in_region.min.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_in_region.min.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_in_region.min.peak_burst:device=0',
#  'cuda:::dram__cycles_in_region.min.peak_burst_active:device=0',
#  'cuda:::dram__cycles_in_region.min.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_in_region.min.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_in_region.min.peak_burst_region:device=0',
#  'cuda:::dram__cycles_in_region.min.peak_sustained:device=0',
#  'cuda:::dram__cycles_in_region.min.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_in_region.min.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_in_region.min.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_in_region.min.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_in_region.min.per_cycle_active:device=0',
#  'cuda:::dram__cycles_in_region.min.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_in_region.min.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_in_region.min.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_in_region.min.per_second:device=0',
#  'cuda:::dram__cycles_in_region.sum:device=0',
#  'cuda:::dram__cycles_in_region.sum.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__cycles_in_region.sum.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_in_region.sum.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__cycles_in_region.sum.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__cycles_in_region.sum.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__cycles_in_region.sum.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_in_region.sum.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_in_region.sum.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__cycles_in_region.sum.peak_burst:device=0',
#  'cuda:::dram__cycles_in_region.sum.peak_burst_active:device=0',
#  'cuda:::dram__cycles_in_region.sum.peak_burst_elapsed:device=0',
#  'cuda:::dram__cycles_in_region.sum.peak_burst_frame:device=0',
#  'cuda:::dram__cycles_in_region.sum.peak_burst_region:device=0',
#  'cuda:::dram__cycles_in_region.sum.peak_sustained:device=0',
#  'cuda:::dram__cycles_in_region.sum.peak_sustained_active:device=0',
#  'cuda:::dram__cycles_in_region.sum.peak_sustained_elapsed:device=0',
#  'cuda:::dram__cycles_in_region.sum.peak_sustained_frame:device=0',
#  'cuda:::dram__cycles_in_region.sum.peak_sustained_region:device=0',
#  'cuda:::dram__cycles_in_region.sum.per_cycle_active:device=0',
#  'cuda:::dram__cycles_in_region.sum.per_cycle_elapsed:device=0',
#  'cuda:::dram__cycles_in_region.sum.per_cycle_in_frame:device=0',
#  'cuda:::dram__cycles_in_region.sum.per_cycle_in_region:device=0',
#  'cuda:::dram__cycles_in_region.sum.per_second:device=0',
#  'cuda:::dram__sectors.avg:device=0',
#  'cuda:::dram__sectors.avg.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__sectors.avg.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__sectors.avg.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__sectors.avg.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__sectors.avg.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__sectors.avg.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__sectors.avg.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__sectors.avg.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__sectors.avg.peak_burst:device=0',
#  'cuda:::dram__sectors.avg.peak_burst_active:device=0',
#  'cuda:::dram__sectors.avg.peak_burst_elapsed:device=0',
#  'cuda:::dram__sectors.avg.peak_burst_frame:device=0',
#  'cuda:::dram__sectors.avg.peak_burst_region:device=0',
#  'cuda:::dram__sectors.avg.peak_sustained:device=0',
#  'cuda:::dram__sectors.avg.peak_sustained_active:device=0',
#  'cuda:::dram__sectors.avg.peak_sustained_elapsed:device=0',
#  'cuda:::dram__sectors.avg.peak_sustained_frame:device=0',
#  'cuda:::dram__sectors.avg.peak_sustained_region:device=0',
#  'cuda:::dram__sectors.avg.per_cycle_active:device=0',
#  'cuda:::dram__sectors.avg.per_cycle_elapsed:device=0',
#  'cuda:::dram__sectors.avg.per_cycle_in_frame:device=0',
#  'cuda:::dram__sectors.avg.per_cycle_in_region:device=0',
#  'cuda:::dram__sectors.avg.per_second:device=0',
#  'cuda:::dram__sectors.max:device=0',
#  'cuda:::dram__sectors.max.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__sectors.max.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__sectors.max.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__sectors.max.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__sectors.max.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__sectors.max.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__sectors.max.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__sectors.max.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__sectors.max.peak_burst:device=0',
#  'cuda:::dram__sectors.max.peak_burst_active:device=0',
#  'cuda:::dram__sectors.max.peak_burst_elapsed:device=0',
#  'cuda:::dram__sectors.max.peak_burst_frame:device=0',
#  'cuda:::dram__sectors.max.peak_burst_region:device=0',
#  'cuda:::dram__sectors.max.peak_sustained:device=0',
#  'cuda:::dram__sectors.max.peak_sustained_active:device=0',
#  'cuda:::dram__sectors.max.peak_sustained_elapsed:device=0',
#  'cuda:::dram__sectors.max.peak_sustained_frame:device=0',
#  'cuda:::dram__sectors.max.peak_sustained_region:device=0',
#  'cuda:::dram__sectors.max.per_cycle_active:device=0',
#  'cuda:::dram__sectors.max.per_cycle_elapsed:device=0',
#  'cuda:::dram__sectors.max.per_cycle_in_frame:device=0',
#  'cuda:::dram__sectors.max.per_cycle_in_region:device=0',
#  'cuda:::dram__sectors.max.per_second:device=0',
#  'cuda:::dram__sectors.min:device=0',
#  'cuda:::dram__sectors.min.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__sectors.min.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__sectors.min.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__sectors.min.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__sectors.min.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__sectors.min.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__sectors.min.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__sectors.min.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__sectors.min.peak_burst:device=0',
#  'cuda:::dram__sectors.min.peak_burst_active:device=0',
#  'cuda:::dram__sectors.min.peak_burst_elapsed:device=0',
#  'cuda:::dram__sectors.min.peak_burst_frame:device=0',
#  'cuda:::dram__sectors.min.peak_burst_region:device=0',
#  'cuda:::dram__sectors.min.peak_sustained:device=0',
#  'cuda:::dram__sectors.min.peak_sustained_active:device=0',
#  'cuda:::dram__sectors.min.peak_sustained_elapsed:device=0',
#  'cuda:::dram__sectors.min.peak_sustained_frame:device=0',
#  'cuda:::dram__sectors.min.peak_sustained_region:device=0',
#  'cuda:::dram__sectors.min.per_cycle_active:device=0',
#  'cuda:::dram__sectors.min.per_cycle_elapsed:device=0',
#  'cuda:::dram__sectors.min.per_cycle_in_frame:device=0',
#  'cuda:::dram__sectors.min.per_cycle_in_region:device=0',
#  'cuda:::dram__sectors.min.per_second:device=0',
#  'cuda:::dram__sectors.sum:device=0',
#  'cuda:::dram__sectors.sum.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__sectors.sum.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__sectors.sum.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__sectors.sum.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__sectors.sum.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__sectors.sum.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__sectors.sum.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__sectors.sum.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__sectors.sum.peak_burst:device=0',
#  'cuda:::dram__sectors.sum.peak_burst_active:device=0',
#  'cuda:::dram__sectors.sum.peak_burst_elapsed:device=0',
#  'cuda:::dram__sectors.sum.peak_burst_frame:device=0',
#  'cuda:::dram__sectors.sum.peak_burst_region:device=0',
#  'cuda:::dram__sectors.sum.peak_sustained:device=0',
#  'cuda:::dram__sectors.sum.peak_sustained_active:device=0',
#  'cuda:::dram__sectors.sum.peak_sustained_elapsed:device=0',
#  'cuda:::dram__sectors.sum.peak_sustained_frame:device=0',
#  'cuda:::dram__sectors.sum.peak_sustained_region:device=0',
#  'cuda:::dram__sectors.sum.per_cycle_active:device=0',
#  'cuda:::dram__sectors.sum.per_cycle_elapsed:device=0',
#  'cuda:::dram__sectors.sum.per_cycle_in_frame:device=0',
#  'cuda:::dram__sectors.sum.per_cycle_in_region:device=0',
#  'cuda:::dram__sectors.sum.per_second:device=0',
#  'cuda:::dram__sectors_read.avg:device=0',
#  'cuda:::dram__sectors_read.avg.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__sectors_read.avg.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__sectors_read.avg.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__sectors_read.avg.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__sectors_read.avg.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__sectors_read.avg.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__sectors_read.avg.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__sectors_read.avg.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__sectors_read.avg.peak_burst:device=0',
#  'cuda:::dram__sectors_read.avg.peak_burst_active:device=0',
#  'cuda:::dram__sectors_read.avg.peak_burst_elapsed:device=0',
#  'cuda:::dram__sectors_read.avg.peak_burst_frame:device=0',
#  'cuda:::dram__sectors_read.avg.peak_burst_region:device=0',
#  'cuda:::dram__sectors_read.avg.peak_sustained:device=0',
#  'cuda:::dram__sectors_read.avg.peak_sustained_active:device=0',
#  'cuda:::dram__sectors_read.avg.peak_sustained_elapsed:device=0',
#  'cuda:::dram__sectors_read.avg.peak_sustained_frame:device=0',
#  'cuda:::dram__sectors_read.avg.peak_sustained_region:device=0',
#  'cuda:::dram__sectors_read.avg.per_cycle_active:device=0',
#  'cuda:::dram__sectors_read.avg.per_cycle_elapsed:device=0',
#  'cuda:::dram__sectors_read.avg.per_cycle_in_frame:device=0',
#  'cuda:::dram__sectors_read.avg.per_cycle_in_region:device=0',
#  'cuda:::dram__sectors_read.avg.per_second:device=0',
#  'cuda:::dram__sectors_read.max:device=0',
#  'cuda:::dram__sectors_read.max.pct_of_peak_burst_active:device=0',
#  'cuda:::dram__sectors_read.max.pct_of_peak_burst_elapsed:device=0',
#  'cuda:::dram__sectors_read.max.pct_of_peak_burst_frame:device=0',
#  'cuda:::dram__sectors_read.max.pct_of_peak_burst_region:device=0',
#  'cuda:::dram__sectors_read.max.pct_of_peak_sustained_active:device=0',
#  'cuda:::dram__sectors_read.max.pct_of_peak_sustained_elapsed:device=0',
#  'cuda:::dram__sectors_read.max.pct_of_peak_sustained_frame:device=0',
#  'cuda:::dram__sectors_read.max.pct_of_peak_sustained_region:device=0',
#  'cuda:::dram__sectors_read.max.peak_burst:device=0',
#  'cuda:::dram__sectors_read.max.peak_burst_active:device=0',
#  'cuda:::dram__sectors_read.max.peak_burst_elapsed:device=0',
#  'cuda:::dram__sectors_read.max.peak_burst_frame:device=0',
#  'cuda:::dram__sectors_read.max.peak_burst_region:device=0',
#  'cuda:::dram__sectors_read.max.peak_sustained:device=0',
#  'cuda:::dram__sectors_read.max.peak_sustained_active:device=0',
#  'cuda:::dram__sectors_read.max.peak_sustained_elapsed:device=0',
#  ...]

# %% [markdown]
# We will do some actual measurement in the next tutorial.

# %% [markdown]
# ## Preset events

# %%
papi_avail()
# Out:
# PAPI_L1_ICM L1I cache misses
# PAPI_L2_DCM L2D cache misses
# PAPI_L2_ICM L2I cache misses
# PAPI_L3_DCM L3D cache misses
# PAPI_L3_ICM L3I cache misses
# PAPI_L1_TCM L1 cache misses
# PAPI_L2_TCM L2 cache misses
# PAPI_L3_TCM L3 cache misses
# PAPI_CA_SNP Snoop Requests
# PAPI_CA_SHR Ex Acces shared CL
# PAPI_CA_CLN Ex Access clean CL
# PAPI_CA_INV Cache ln invalid
# PAPI_CA_ITV Cache ln intervene
# PAPI_L3_LDM L3 load misses
# PAPI_L3_STM L3 store misses
# PAPI_BRU_IDL Branch idle cycles
# PAPI_FXU_IDL IU idle cycles
# PAPI_FPU_IDL FPU idle cycles
# PAPI_LSU_IDL L/SU idle cycles
# PAPI_TLB_DM Data TLB misses
# PAPI_TLB_IM Instr TLB misses
# PAPI_TLB_TL Total TLB misses
# PAPI_L1_LDM L1 load misses
# PAPI_L1_STM L1 store misses
# PAPI_L2_LDM L2 load misses
# PAPI_L2_STM L2 store misses
# PAPI_BTAC_M Br targt addr miss
# PAPI_PRF_DM Data prefetch miss
# PAPI_L3_DCH L3D cache hits
# PAPI_TLB_SD TLB shootdowns
# PAPI_CSR_FAL Failed store cond
# PAPI_CSR_SUC Good store cond
# PAPI_CSR_TOT Total store cond
# PAPI_MEM_SCY Stalled mem cycles
# PAPI_MEM_RCY Stalled rd cycles
# PAPI_MEM_WCY Stalled wr cycles
# PAPI_STL_ICY No instr issue
# PAPI_FUL_ICY Max instr issue
# PAPI_STL_CCY No instr done
# PAPI_FUL_CCY Max instr done
# PAPI_HW_INT Hdw interrupts
# PAPI_BR_UCN Uncond branch
# PAPI_BR_CN Cond branch
# PAPI_BR_TKN Cond branch taken
# PAPI_BR_NTK Cond br not taken
# PAPI_BR_MSP Cond br mspredictd
# PAPI_BR_PRC Cond br predicted
# PAPI_FMA_INS FMAs completed
# PAPI_TOT_IIS Instr issued
# PAPI_TOT_INS Instr completed
# PAPI_INT_INS Int instructions
# PAPI_FP_INS FP instructions
# PAPI_LD_INS Loads
# PAPI_SR_INS Stores
# PAPI_BR_INS Branches
# PAPI_VEC_INS Vector/SIMD instr
# PAPI_RES_STL Stalled res cycles
# PAPI_FP_STAL Stalled FPU cycles
# PAPI_TOT_CYC Total cycles
# PAPI_LST_INS L/S completed
# PAPI_SYC_INS Syncs completed
# PAPI_L1_DCH L1D cache hits
# PAPI_L2_DCH L2D cache hits
# PAPI_L1_DCA L1D cache accesses
# PAPI_L2_DCA L2D cache accesses
# PAPI_L3_DCA L3D cache accesses
# PAPI_L1_DCR L1D cache reads
# PAPI_L2_DCR L2D cache reads
# PAPI_L3_DCR L3D cache reads
# PAPI_L1_DCW L1D cache writes
# PAPI_L2_DCW L2D cache writes
# PAPI_L3_DCW L3D cache writes
# PAPI_L1_ICH L1I cache hits
# PAPI_L2_ICH L2I cache hits
# PAPI_L3_ICH L3I cache hits
# PAPI_L1_ICA L1I cache accesses
# PAPI_L2_ICA L2I cache accesses
# PAPI_L3_ICA L3I cache accesses
# PAPI_L1_ICR L1I cache reads
# PAPI_L2_ICR L2I cache reads
# PAPI_L3_ICR L3I cache reads
# PAPI_L1_ICW L1I cache writes
# PAPI_L2_ICW L2I cache writes
# PAPI_L3_ICW L3I cache writes
# PAPI_L1_TCH L1 cache hits
# PAPI_L2_TCH L2 cache hits
# PAPI_L3_TCH L3 cache hits
# PAPI_L1_TCA L1 cache accesses
# PAPI_L2_TCA L2 cache accesses
# PAPI_L3_TCA L3 cache accesses
# PAPI_L1_TCR L1 cache reads
# PAPI_L2_TCR L2 cache reads
# PAPI_L3_TCR L3 cache reads
# PAPI_L1_TCW L1 cache writes
# PAPI_L2_TCW L2 cache writes
# PAPI_L3_TCW L3 cache writes
# PAPI_FML_INS FPU multiply
# PAPI_FAD_INS FPU add
# PAPI_FDV_INS FPU divide
# PAPI_FSQ_INS FPU square root
# PAPI_FNV_INS FPU inverse
# PAPI_FP_OPS FP operations
# PAPI_SP_OPS SP operations
# PAPI_DP_OPS DP operations
# PAPI_VEC_SP SP Vector/SIMD instr
# PAPI_VEC_DP DP Vector/SIMD instr
# PAPI_REF_CYC Reference cycles

# %% [markdown]
# ## Accurate timing functions
#
# `CyPAPI` ports several accurate timing functions. Few examples are shown below

# %%
from time import sleep
start = pyPAPI_get_real_usec()
sleep(1)
stop = pyPAPI_get_real_usec()
print(f'Time elapsed = {stop-start} us')
# Out:
# Time elapsed = 1000356 us

# %%
start = pyPAPI_get_virt_usec()
sleep(1)
stop = pyPAPI_get_virt_usec()
print(f'Time elapsed = {stop-start} us')
# Out:
# Time elapsed = 152 us
